# %% [markdown]
# ##Setup
#
# You will need to make a copy of this Colab notebook in your Google Drive before you can edit the homework files. You can do so with **File &rarr; Save a copy in Drive**.

# %%
import os
from google_drive_downloader import GoogleDriveDownloader as gdd

# Need to download the Omniglot dataset -- DON'T MODIFY THIS CELL
if not os.path.isdir('./omniglot_resized'):
    gdd.download_file_from_google_drive(file_id='1iaSFXIYC3AB8q9K_M-oVMa4pmB7yKMtI',
                                        dest_path='./omniglot_resized.zip',
                                        unzip=True)
    
assert os.path.isdir('./omniglot_resized')
# Out:
# Downloading 1iaSFXIYC3AB8q9K_M-oVMa4pmB7yKMtI into ./omniglot_resized.zip... Done.
# Unzipping...Done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import os
import random
import tensorflow as tf
from scipy import misc


def get_images(paths, labels, nb_samples=None, shuffle=True):
    """
    Takes a set of character folders and labels and returns paths to image files
    paired with labels.
    Args:
        paths: A list of character folders
        labels: List or numpy array of same length as paths
        nb_samples: Number of images to retrieve per character
    Returns:
        List of (label, image_path) tuples
    """
    if nb_samples is not None:
        sampler = lambda x: random.sample(x, nb_samples)
    else:
        sampler = lambda x: x
    images_labels = [(i, os.path.join(path, image))
                     for i, path in zip(labels, paths)
                     for image in sampler(os.listdir(path))]
    if shuffle:
        random.shuffle(images_labels)
    return images_labels


def image_file_to_array(filename, dim_input):
    """
    Takes an image path and returns numpy array
    Args:
        filename: Image filename
        dim_input: Flattened shape of image
    Returns:
        1 channel image
    """
    import imageio
    image = imageio.imread(filename)  # misc.imread(filename)
    image = image.reshape([dim_input])
    image = image.astype(np.float32) / 255.0
    image = 1.0 - image
    return image


class DataGenerator(object):
    """
    Data Generator capable of generating batches of Omniglot data.
    A "class" is considered a class of omniglot digits.
    """

    def __init__(self, num_classes, num_samples_per_class, config={}):
        """
        Args:
            num_classes: Number of classes for classification (K-way)
            num_samples_per_class: num samples to generate per class in one batch
            batch_size: size of meta batch size (e.g. number of functions)
        """
        self.num_samples_per_class = num_samples_per_class
        self.num_classes = num_classes

        data_folder = config.get('data_folder', './omniglot_resized')
        self.img_size = config.get('img_size', (28, 28))

        self.dim_input = np.prod(self.img_size)
        self.dim_output = self.num_classes

        character_folders = [os.path.join(data_folder, family, character)
                             for family in os.listdir(data_folder)
                             if os.path.isdir(os.path.join(data_folder, family))
                             for character in os.listdir(os.path.join(data_folder, family))
                             if os.path.isdir(os.path.join(data_folder, family, character))]

        random.seed(1)
        random.shuffle(character_folders)
        num_val = 100
        num_train = 1100
        self.metatrain_character_folders = character_folders[: num_train]
        self.metaval_character_folders = character_folders[
            num_train:num_train + num_val]
        self.metatest_character_folders = character_folders[
            num_train + num_val:]

    def sample_batch(self, batch_type, batch_size):
        """
        Samples a batch for training, validation, or testing
        Args:
            batch_type: train/val/test
        Returns:
            A a tuple of (1) Image batch and (2) Label batch where
            image batch has shape [B, K, N, 784] and label batch has shape [B, K, N, N]
            where B is batch size, K is number of samples per class, N is number of classes
        """
        if batch_type == "train":
            folders = self.metatrain_character_folders
        elif batch_type == "val":
            folders = self.metaval_character_folders
        else:
            folders = self.metatest_character_folders

        #############################
        #### YOUR CODE GOES HERE ####

        K = self.num_samples_per_class
        N = self.num_classes

        all_image_batches = []
        all_label_batches = []

        for b in range(batch_size):
          char_folders = random.sample(folders, N)

          labels = list(range(N))
          random.shuffle(labels)
          imagepath_label_pairs = get_images(char_folders, labels, K, shuffle=False)

          train_image_labels = []
          test_image_labels  = [] 

          for i in range(N):
            train_image_labels += imagepath_label_pairs[(i*K):((i+1)*K)-1]
            test_image_labels.append(imagepath_label_pairs[((i+1)*K)-1])

          random.shuffle(train_image_labels)
          random.shuffle(test_image_labels)

          all_image_labels = train_image_labels + test_image_labels

          images = np.array([image_file_to_array(image_label[1], self.dim_input) for image_label in all_image_labels])
          labels = np.array([image_label[0] for image_label in all_image_labels], dtype = np.int8)

          labels_one_hot = np.zeros((labels.size, self.num_classes))
          labels_one_hot[np.arange(labels.size), labels] = 1

          labels_one_hot = np.vstack(labels_one_hot).reshape((self.num_samples_per_class, self.num_classes, -1))  # K, N, N

          images = np.vstack(images).reshape((self.num_samples_per_class, self.num_classes, -1))  # K x N x 784

          all_image_batches.append(images)
          all_label_batches.append(labels_one_hot)

        all_image_batches = np.stack(all_image_batches).astype(np.float32)
        all_label_batches = np.stack(all_label_batches).astype(np.float32)

        #############################
        #return all_image_batches.astype(np.float32), all_label_batches.astype(np.float32)
        return all_image_batches, all_label_batches

# %%
import numpy as np
import random
import tensorflow as tf
from tensorflow.keras import layers


class MANN(tf.keras.Model):

    def __init__(self, num_classes, samples_per_class):
        super(MANN, self).__init__()
        self.num_classes = num_classes
        self.samples_per_class = samples_per_class
        #self.cnn = tf.keras.layers.
        self.layer1 = tf.keras.layers.LSTM(128, return_sequences=True)
        self.layer2 = tf.keras.layers.LSTM(num_classes, return_sequences=True)

    def call(self, input_images, input_labels):
        """
        MANN
        Args:
            input_images: [B, K+1, N, 784] flattened images
            labels: [B, K+1, N, N] ground truth labels
        Returns:
            [B, K+1, N, N] predictions
        """
        #############################
        #### YOUR CODE GOES HERE ####
        in_zero = input_labels[:, -1:, :, :] - input_labels[:, -1:, :, :]
        labels = tf.concat([input_labels[:, :-1, :, :], in_zero], axis=1)
        inputs = tf.concat([input_images, labels], axis=-1)
        inputs = tf.reshape(inputs, [-1, self.num_classes * self.samples_per_class, input_images.shape[-1]+input_labels.shape[-1]])
        inputs = self.layer1(inputs)
        out  = self.layer2(inputs)
        out = tf.reshape(out, [-1, self.samples_per_class, self.num_classes, self.num_classes])
        #############################
        return out

    def loss_function(self, preds, labels):
        """
        Computes MANN loss
        Args:
            preds: [B, K+1, N, N] network output
            labels: [B, K+1, N, N] labels
        Returns:
            scalar loss
        """
        #############################
        #### YOUR CODE GOES HERE ####
        preds = preds[:, -1, :, :]
        labels = labels[:, -1, :, :]
        losses = tf.keras.losses.categorical_crossentropy(labels, preds, from_logits=True)
        loss = tf.reduce_sum(losses)
        return loss
        #############################


@tf.function
def train_step(images, labels, model, optim, eval=False):
    with tf.GradientTape() as tape:
        predictions = model(images, labels)
        loss = model.loss_function(predictions, labels)
    if not eval:
        gradients = tape.gradient(loss, model.trainable_variables)
        optim.apply_gradients(zip(gradients, model.trainable_variables))
    return predictions, loss


def main(num_classes=5, num_samples=1, meta_batch_size=16, random_seed=1234):
    random.seed(random_seed)
    np.random.seed(random_seed)
    tf.random.set_seed(random_seed)

    data_generator = DataGenerator(num_classes, num_samples + 1)

    o = MANN(num_classes, num_samples + 1)
    optim = tf.keras.optimizers.Adam(learning_rate=0.001)

    train_loss = []
    test_loss  = []
    test_acc   = []

    for step in range(50000):
        i, l = data_generator.sample_batch('train', meta_batch_size)
        _, ls = train_step(i, l, o, optim)

        if (step+1) % 100 == 0:
            print("*" * 5 + "Iter " + str(step + 1) + "*" * 5)
            i, l = data_generator.sample_batch('test', 100)
            pred, tls = train_step(i, l, o, optim, eval=True)
            print("Train Loss:", ls.numpy(), "Test Loss:", tls.numpy())
            pred = tf.reshape(pred, [-1, num_samples + 1, num_classes, num_classes])
            pred = tf.math.argmax(pred[:, -1, :, :], axis=2)
            l = tf.math.argmax(l[:, -1, :, :], axis=2)
            acc = tf.reduce_mean(tf.cast(tf.math.equal(pred, l), tf.float32))
            print("Test Accuracy", acc.numpy())
            train_loss.append(ls.numpy())
            test_loss.append(tls.numpy())
            test_acc.append(acc.numpy())

    return train_loss, test_loss, test_acc

# %%
#plotting utility 
import matplotlib.pyplot as plt
import seaborn as sns
#############################
#### YOUR CODE GOES HERE ####

def plot_metrics(x, y, num_classes, samples_per_class, exp_title):
  sns.set(style='darkgrid')
  fig, ax = plt.subplots(figsize = (10,7))
  x = np.array(x)
  y = np.array(y)
  ax.plot(x, y, c='b')

  ax.set_xlabel('Number of Iterations (x100)')
  ax.set_ylabel('Accuracy')
  #ax.set_xticks(x)

  #ax.legend(loc="best")
  ax.set_title('Few shot classification accuracy {}-way and {}-shot'.format(num_classes, samples_per_class))

  fig.savefig('/content/drive/MyDrive/CS330-MetaLearning/Hw1/blackbox_exp_{}.jpg'.format(exp_title))
#############################

# %%
results = main(num_classes=5, num_samples=1, meta_batch_size=16, random_seed=2)
test_acc = results[2]
iterations = range(1, len(test_acc)+1)
plot_metrics(iterations, test_acc, num_classes=5, samples_per_class=1, exp_title='5-Way-1-shot-lr-0.001-optim_steps-50000-lstm_stack2-seed2')
# Out:
# *****Iter 100*****
# Train Loss: 128.886 Test Loss: 804.9387
# Test Accuracy 0.188
# *****Iter 200*****
# Train Loss: 128.61334 Test Loss: 804.8779
# Test Accuracy 0.168
# *****Iter 300*****
# Train Loss: 128.77692 Test Loss: 804.56683
# Test Accuracy 0.226
# *****Iter 400*****
# Train Loss: 128.71942 Test Loss: 804.75916
# Test Accuracy 0.21
# *****Iter 500*****
# Train Loss: 128.75433 Test Loss: 804.6582
# Test Accuracy 0.204
# *****Iter 600*****
# Train Loss: 128.7359 Test Loss: 804.67676
# Test Accuracy 0.2
# *****Iter 700*****
# Train Loss: 128.751 Test Loss: 804.7041
# Test Accuracy 0.234
# *****Iter 800*****
# Train Loss: 128.7542 Test Loss: 804.7054
# Test Accuracy 0.2
# *****Iter 900*****
# Train Loss: 128.75421 Test Loss: 804.7217
# Test Accuracy 0.208
# *****Iter 1000*****
# Train Loss: 128.76703 Test Loss: 804.67773
# Test Accuracy 0.204
# *****Iter 1100*****
# Train Loss: 128.73013 Test Loss: 804.75464
# Test Accuracy 0.19
# *****Iter 1200*****
# Train Loss: 128.76295 Test Loss: 804.7127
# Test Accuracy 0.206
# *****Iter 1300*****
# Train Loss: 128.76009 Test Loss: 804.74396
# Test Accuracy 0.172
# *****Iter 1400*****
# Train Loss: 128.74739 Test Loss: 804.74805
# Test Accuracy 0.192
# *****Iter 1500*****
# Train Loss: 128.75128 Test Loss: 804.72473
# Test Accuracy 0.196
# *****Iter 1600*****
# Train Loss: 128.74588 Test Loss: 804.711
# Test Accuracy 0.204
# *****Iter 1700*****
# Train Loss: 128.76128 Test Loss: 804.7389
# Test Accuracy 0.202
# *****Iter 1800*****
# Train Loss: 128.75748 Test Loss: 804.7223
# Test Accuracy 0.186
# *****Iter 1900*****
# Train Loss: 128.75664 Test Loss: 804.728
# Test Accuracy 0.198
# *****Iter 2000*****
# Train Loss: 128.74863 Test Loss: 804.7081
# Test Accuracy 0.228
# *****Iter 2100*****
# Train Loss: 128.7553 Test Loss: 804.71533
# Test Accuracy 0.2
# *****Iter 2200*****
# Train Loss: 128.76715 Test Loss: 804.76465
# Test Accuracy 0.198
# *****Iter 2300*****
# Train Loss: 128.76405 Test Loss: 804.7474
# Test Accuracy 0.208
# *****Iter 2400*****
# Train Loss: 128.74982 Test Loss: 804.7294
# Test Accuracy 0.196
# *****Iter 2500*****
# Train Loss: 128.75462 Test Loss: 804.7323
# Test Accuracy 0.168
# *****Iter 2600*****
# Train Loss: 128.75598 Test Loss: 804.7177
# Test Accuracy 0.196
# *****Iter 2700*****
# Train Loss: 128.75307 Test Loss: 804.7214
# Test Accuracy 0.198
# *****Iter 2800*****
# Train Loss: 128.75327 Test Loss: 804.71765
# Test Accuracy 0.214
# *****Iter 2900*****
# Train Loss: 128.7543 Test Loss: 804.71826
# Test Accuracy 0.198
# *****Iter 3000*****
# Train Loss: 128.75455 Test Loss: 804.71875
# Test Accuracy 0.2
# *****Iter 3100*****
# Train Loss: 128.75406 Test Loss: 804.7217
# Test Accuracy 0.198
# *****Iter 3200*****
# Train Loss: 128.75638 Test Loss: 804.72125
# Test Accuracy 0.2
# *****Iter 3300*****
# Train Loss: 128.75548 Test Loss: 804.7185
# Test Accuracy 0.204
# *****Iter 3400*****
# Train Loss: 128.75784 Test Loss: 804.735
# Test Accuracy 0.2
# *****Iter 3500*****
# Train Loss: 128.7558 Test Loss: 804.72144
# Test Accuracy 0.192
# *****Iter 3600*****
# Train Loss: 128.75511 Test Loss: 804.7177
Test Loss: 804.7191
# Test Accuracy 0.2
# *****Iter 9500*****
# Train Loss: 128.75505 Test Loss: 804.71893
# Test Accuracy 0.196
# *****Iter 9600*****
# Train Loss: 128.75511 Test Loss: 804.7188
# Test Accuracy 0.218
# *****Iter 9700*****
# Train Loss: 128.75508 Test Loss: 804.7188
# Test Accuracy 0.204
# *****Iter 9800*****
# Train Loss: 128.75505 Test Loss: 804.719
# Test Accuracy 0.196
# *****Iter 9900*****
# Train Loss: 128.75502 Test Loss: 804.71875
# Test Accuracy 0.218
# *****Iter 10000*****
# Train Loss: 128.75507 Test Loss: 804.719
# Test Accuracy 0.202
# *****Iter 10100*****
# Train Loss: 128.75497 Test Loss: 804.7191
# Test Accuracy 0.194
# *****Iter 10200*****
# Train Loss: 128.75499 Test Loss: 804.719
# Test Accuracy 0.188
# *****Iter 10300*****
# Train Loss: 128.75504 Test Loss: 804.7192
# Test Accuracy 0.204
# *****Iter 10400*****
# Train Loss: 128.75513 Test Loss: 804.7186
# Test Accuracy 0.204
# *****Iter 10500*****
# Train Loss: 128.75482 Test Loss: 804.71906
# Test Accuracy 0.2
# *****Iter 10600*****
# Train Loss: 128.75499 Test Loss: 804.719
# Test Accuracy 0.204
# *****Iter 10700*****
# Train Loss: 128.75507 Test Loss: 804.7189
# Test Accuracy 0.208
# *****Iter 10800*****
# Train Loss: 128.75507 Test Loss: 804.7189
# Test Accuracy 0.198
# *****Iter 10900*****
# Train Loss: 128.75505 Test Loss: 804.7189
# Test Accuracy 0.22
# *****Iter 11000*****
# Train Loss: 128.75507 Test Loss: 804.719
# Test Accuracy 0.198
# *****Iter 11100*****
# Train Loss: 128.75508 Test Loss: 804.7189
# Test Accuracy 0.194
# *****Iter 11200*****
# Train Loss: 128.75497 Test Loss: 804.71906
# Test Accuracy 0.184
# *****Iter 11300*****
# Train Loss: 128.755 Test Loss: 804.719
# Test Accuracy 0.204
# *****Iter 11400*****
# Train Loss: 128.75502 Test Loss: 804.719
# Test Accuracy 0.204
# *****Iter 11500*****
# Train Loss: 128.755 Test Loss: 804.7189
# Test Accuracy 0.2
# *****Iter 11600*****
# Train Loss: 128.755 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 11700*****
# Train Loss: 128.755 Test Loss: 804.7186
# Test Accuracy 0.2
# *****Iter 11800*****
# Train Loss: 128.755 Test Loss: 804.7192
# Test Accuracy 0.2
# *****Iter 11900*****
# Train Loss: 128.75504 Test Loss: 804.71893
# Test Accuracy 0.2
# *****Iter 12000*****
# Train Loss: 128.755 Test Loss: 804.7189
# Test Accuracy 0.2
# *****Iter 12100*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 12200*****
# Train Loss: 128.75504 Test Loss: 804.71893
# Test Accuracy 0.2
# *****Iter 12300*****
# Train Loss: 128.75507 Test Loss: 804.71906
# Test Accuracy 0.2
# *****Iter 12400*****
# Train Loss: 128.75504 Test Loss: 804.71893
# Test Accuracy 0.202
# *****Iter 12500*****
# Train Loss: 128.75502 Test Loss: 804.719
# Test Accuracy 0.188
# *****Iter 12600*****
# Train Loss: 128.75505 Test Loss: 804.719
# Test Accuracy 0.21
# *****Iter 12700*****
# Train Loss: 128.75502 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 12800*****
# Train Loss: 128.75504 Test Loss: 804.71893
# Test Accuracy 0.204
# *****Iter 12900*****
# Train Loss: 128.75504 Test Loss: 804.71893
# Test Accuracy 0.202
# *****Iter 13000*****
# Train Loss: 128.75502 Test Loss: 804.719
# Test Accuracy 0.172
# *****Iter 13100*****
# Train Loss: 128.75504 Test Loss: 804.71893
# Test Accuracy 0.212
# *****Iter 13200*****
# Train Loss: 128.75504 Test Loss: 804.71893
# Test Accuracy 0.218
# *****Iter 13300*****
# Train Loss: 128.755 Test Loss: 804.719
# Test Accuracy 0.186
# *****Iter 13400*****
# Train Loss: 128.75508 Test Loss: 804.7188
# Test Accuracy 0.2
# *****Iter 13500*****
# Train Loss: 128.75505 Test Loss: 804.719
# Test Accuracy 0.208
# *****Iter 13600*****
# Train Loss: 128.75507 Test Loss: 804.71893
# Test Accuracy 0.2
# *****Iter 13700*****
# Train Loss: 128.75504 Test Loss: 804.71893
# Test Accuracy 0.202
# *****Iter 13800*****
# Train Loss: 128.75505 Test Loss: 804.719
# Test Accuracy 0.204
# *****Iter 13900*****
# Train Loss: 128.75504 Test Loss: 804.71893
# Test Accuracy 0.2
# *****Iter 14000*****
# Train Loss: 128.75505 Test Loss: 804.719
# Test Accuracy 0.194
# *****Iter 14100*****
# Train Loss: 128.755 Test Loss: 804.71906
# Test Accuracy 0.17
# *****Iter 14200*****
# Train Loss: 128.75505 Test Loss: 804.719
# Test Accuracy 0.198
# *****Iter 14300*****
# Train Loss: 128.75502 Test Loss: 804.719
# Test Accuracy 0.202
# *****Iter 14400*****
# Train Loss: 128.75504 Test Loss: 804.71893
# Test Accuracy 0.198
# *****Iter 14500*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.202
# *****Iter 14600*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.186
# *****Iter 14700*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.202
# *****Iter 14800*****
# Train Loss: 128.75504 Test Loss: 804.71906
# Test Accuracy 0.2
# *****Iter 14900*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 15000*****
# Train Loss: 128.75502 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 15100*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 15200*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 15300*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 15400*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.188
# *****Iter 15500*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.188
# *****Iter 15600*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.198
# *****Iter 15700*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.216
# *****Iter 15800*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.192
# *****Iter 15900*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 16000*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 16100*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.198
# *****Iter 16200*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.208
# *****Iter 16300*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 16400*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.19
# *****Iter 16500*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.194
# *****Iter 16600*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.206
# *****Iter 16700*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.182
# *****Iter 16800*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.184
# *****Iter 16900*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.202
# *****Iter 17000*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.196
# *****Iter 17100*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.192
# *****Iter 17200*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.198
# *****Iter 17300*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 17400*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 17500*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.19
# *****Iter 17600*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.188
# *****Iter 17700*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.19
# *****Iter 17800*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.18
# *****Iter 17900*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 18000*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 18100*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.198
# *****Iter 18200*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 18300*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 18400*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 18500*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 18600*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 18700*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 18800*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 18900*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 19000*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 19100*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.212
# *****Iter 19200*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 19300*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 19400*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.196
# *****Iter 19500*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 19600*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 19700*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 19800*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 19900*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.194
# *****Iter 20000*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 20100*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.208
# *****Iter 20200*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 20300*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.178
# *****Iter 20400*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 20500*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 20600*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 20700*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 20800*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 20900*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 21000*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 21100*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 21200*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.202
# *****Iter 21300*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 21400*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 21500*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 21600*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 21700*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 21800*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 21900*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 22000*****
# Train Loss: 128.75502 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 22100*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 22200*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 22300*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 22400*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.202
# *****Iter 22500*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 22600*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 22700*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 22800*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.21
# *****Iter 22900*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 23000*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.196
# *****Iter 23100*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.198
# *****Iter 23200*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 23300*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.198
# *****Iter 23400*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 23500*****
# Train Loss: 128.75502 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 23600*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 23700*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 23800*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 23900*****
# Train Loss: 128.75502 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 24000*****
# Train Loss: 128.75502 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 24100*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 24200*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 24300*****
# Train Loss: 128.75502 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 24400*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.198
# *****Iter 24500*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 24600*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 24700*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 24800*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 24900*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 25000*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 25100*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 25200*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 25300*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 25400*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 25500*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 25600*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 25700*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 25800*****
# Train Loss: 128.75502 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 25900*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 26000*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 26100*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 26200*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 26300*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 26400*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 26500*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 26600*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 26700*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 26800*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 26900*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 27000*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 27100*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 27200*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 27300*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 27400*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 27500*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 27600*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 27700*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 27800*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 27900*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 28000*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 28100*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 28200*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 28300*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 28400*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 28500*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 28600*****
# Train Loss: 128.75499 Test Loss: 804.7191
# Test Accuracy 0.198
# *****Iter 28700*****
# Train Loss: 128.75494 Test Loss: 804.7219
# Test Accuracy 0.2
# *****Iter 28800*****
# Train Loss: 128.75488 Test Loss: 804.7191
# Test Accuracy 0.2
# *****Iter 28900*****
# Train Loss: 128.75505 Test Loss: 804.71906
# Test Accuracy 0.2
# *****Iter 29000*****
# Train Loss: 128.75502 Test Loss: 804.71875
# Test Accuracy 0.2
# *****Iter 29100*****
# Train Loss: 128.75494 Test Loss: 804.71857
# Test Accuracy 0.2
# *****Iter 29200*****
# Train Loss: 128.75511 Test Loss: 804.71924
# Test Accuracy 0.2
# *****Iter 29300*****
# Train Loss: 128.755 Test Loss: 804.7195
# Test Accuracy 0.2
# *****Iter 29400*****
# Train Loss: 128.75494 Test Loss: 804.7191
# Test Accuracy 0.2
# *****Iter 29500*****
# Train Loss: 128.75508 Test Loss: 804.7184
# Test Accuracy 0.2
# *****Iter 29600*****
# Train Loss: 128.75505 Test Loss: 804.7186
# Test Accuracy 0.2
# *****Iter 29700*****
# Train Loss: 128.75497 Test Loss: 804.7191
# Test Accuracy 0.2
# *****Iter 29800*****
# Train Loss: 128.75496 Test Loss: 804.7186
# Test Accuracy 0.2
# *****Iter 29900*****
# Train Loss: 128.75508 Test Loss: 804.7191
# Test Accuracy 0.2
# *****Iter
Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 34400*****
# Train Loss: 128.75508 Test Loss: 804.71893
# Test Accuracy 0.2
# *****Iter 34500*****
# Train Loss: 128.75499 Test Loss: 804.7191
# Test Accuracy 0.2
# *****Iter 34600*****
# Train Loss: 128.75497 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 34700*****
# Train Loss: 128.75508 Test Loss: 804.7191
# Test Accuracy 0.2
# *****Iter 34800*****
# Train Loss: 128.75505 Test Loss: 804.7189
# Test Accuracy 0.2
# *****Iter 34900*****
# Train Loss: 128.75507 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 35000*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 35100*****
# Train Loss: 128.75497 Test Loss: 804.7189
# Test Accuracy 0.2
# *****Iter 35200*****
# Train Loss: 128.75505 Test Loss: 804.71893
# Test Accuracy 0.2
# *****Iter 35300*****
# Train Loss: 128.75502 Test Loss: 804.71906
# Test Accuracy 0.2
# *****Iter 35400*****
# Train Loss: 128.75505 Test Loss: 804.71906
# Test Accuracy 0.2
# *****Iter 35500*****
# Train Loss: 128.75502 Test Loss: 804.7189
# Test Accuracy 0.2
# *****Iter 35600*****
# Train Loss: 128.755 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 35700*****
# Train Loss: 128.75502 Test Loss: 804.7189
# Test Accuracy 0.2
# *****Iter 35800*****
# Train Loss: 128.75507 Test Loss: 804.71893
# Test Accuracy 0.2
# *****Iter 35900*****
# Train Loss: 128.75504 Test Loss: 804.71893
# Test Accuracy 0.2
# *****Iter 36000*****
# Train Loss: 128.75502 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 36100*****
# Train Loss: 128.75502 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 36200*****
# Train Loss: 128.75504 Test Loss: 804.719
# Test Accuracy 0.2
# *****Iter 36300*****
# Train Loss: 128.75502 Test Loss: 804.71893
# Test Accuracy 0.2
# *****Iter 36400*****
# Train Loss: 128.75497 Test Loss: 804.71875
# Test Accuracy 0.2
# *****Iter 36500*****
# Train Loss: 128.75348 Test Loss: 804.70966
# Test Accuracy 0.2
# *****Iter 36600*****
# Train Loss: 128.75455 Test Loss: 804.72076
# Test Accuracy 0.2
# *****Iter 36700*****
# Train Loss: 128.76234 Test Loss: 804.708
# Test Accuracy 0.2
# *****Iter 36800*****
# Train Loss: 128.75502 Test Loss: 804.7171
# Test Accuracy 0.2
# *****Iter 36900*****
# Train Loss: 128.7606 Test Loss: 804.717
# Test Accuracy 0.2
# *****Iter 37000*****
# Train Loss: 128.75188 Test Loss: 804.7127
# Test Accuracy 0.2
# *****Iter 37100*****
# Train Loss: 128.75812 Test Loss: 804.714
# Test Accuracy 0.2
# *****Iter 37200*****
# Train Loss: 128.72766 Test Loss: 804.6864
# Test Accuracy 0.2
# *****Iter 37300*****
# Train Loss: 128.73853 Test Loss: 802.37836
# Test Accuracy 0.2
# *****Iter 37400*****
# Train Loss: 128.34094 Test Loss: 802.2145
# Test Accuracy 0.2
# *****Iter 37500*****
# Train Loss: 127.952194 Test Loss: 801.13654
# Test Accuracy 0.188
# *****Iter 37600*****
# Train Loss: 128.33224 Test Loss: 801.0023
# Test Accuracy 0.176
# *****Iter 37700*****
# Train Loss: 128.30792 Test Loss: 801.0957
# Test Accuracy 0.192
# *****Iter 37800*****
# Train Loss: 128.32571 Test Loss: 804.04333
# Test Accuracy 0.198
# *****Iter 37900*****
# Train Loss: 128.07295 Test Loss: 799.3994
# Test Accuracy 0.214
# *****Iter 38000*****
# Train Loss: 129.04008 Test Loss: 798.41046
# Test Accuracy 0.196
# *****Iter 38100*****
